# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\water_potability.csv")
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# ## EDA

# %%
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
df.shape
# Out:
# (3276, 10)

# %%
df.size
# Out:
# 32760

# %%
df.mean()
# Out:
# ph                     7.080795
# Hardness             196.369496
# Solids             22014.092526
# Chloramines            7.122277
# Sulfate              333.775777
# Conductivity         426.205111
# Organic_carbon        14.284970
# Trihalomethanes       66.396293
# Turbidity              3.966786
# Potability             0.390110
# dtype: float64

# %%
df.median()
# Out:
# ph                     7.036752
# Hardness             196.967627
# Solids             20927.833607
# Chloramines            7.130299
# Sulfate              333.073546
# Conductivity         421.884968
# Organic_carbon        14.218338
# Trihalomethanes       66.622485
# Turbidity              3.955028
# Potability             0.000000
# dtype: float64

# %%
df.mode()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     0.000000   47.432000    320.942611     0.352000  129.000000
# 1     0.227499   73.492234    728.750830     0.530351  180.206746
# 2     0.975578   77.459586   1198.943699     1.390871  182.397370
# 3     0.989912   81.710895   1351.906979     1.683993  187.170714
# 4     1.431782   94.091307   1372.091043     1.920271  187.424131
# ...        ...         ...           ...          ...         ...
# 3271       NaN  307.706024  56320.586979    12.626900         NaN
# 3272       NaN  308.253833  56351.396304    12.653362         NaN
# 3273       NaN  311.383956  56488.672413    12.912187         NaN
# 3274       NaN  317.338124  56867.859236    13.043806         NaN
# 3275       NaN  323.124000  61227.196008    13.127000         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       181.483754        2.200000         0.738000   1.450000         0.0
# ...

# %%
df.skew()
# Out:
# ph                 0.025630
# Hardness          -0.039342
# Solids             0.621634
# Chloramines       -0.012098
# Sulfate           -0.035947
# Conductivity       0.264490
# Organic_carbon     0.025533
# Trihalomethanes   -0.083031
# Turbidity         -0.007817
# Potability         0.450784
# dtype: float64

# %%
df.kurtosis()
# Out:
# ph                 0.720316
# Hardness           0.615772
# Solids             0.442826
# Chloramines        0.589901
# Sulfate            0.648263
# Conductivity      -0.277093
# Organic_carbon     0.044409
# Trihalomethanes    0.238597
# Turbidity         -0.062801
# Potability        -1.797892
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.describe().T
# Out:
#                   count          mean          std         min           25%  \
# ph               2785.0      7.080795     1.594320    0.000000      6.093092
# Hardness         3276.0    196.369496    32.879761   47.432000    176.850538
# Solids           3276.0  22014.092526  8768.570828  320.942611  15666.690297
# Chloramines      3276.0      7.122277     1.583085    0.352000      6.127421
# Sulfate          2495.0    333.775777    41.416840  129.000000    307.699498
# Conductivity     3276.0    426.205111    80.824064  181.483754    365.734414
# Organic_carbon   3276.0     14.284970     3.308162    2.200000     12.065801
# Trihalomethanes  3114.0     66.396293    16.175008    0.738000     55.844536
# Turbidity        3276.0      3.966786     0.780382    1.450000      3.439711
# Potability       3276.0      0.390110     0.487849    0.000000      0.000000
#
#                           50%           75%           max
# ph                   7.036752      8.062066     14.000000
# ...

# %%
df.isna().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
#handling missing values
df['ph']=df['ph'].fillna(df['ph'].mean())
df['Sulfate']=df['Sulfate'].fillna(df['Sulfate'].mean())
df['Trihalomethanes']=df['Trihalomethanes'].fillna(df['Trihalomethanes'].mean())

# %%
df.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Seperate X and Y

# %%
X=df.iloc[:,:9]
X
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3271    1
# 3272    1
# 3273    1
# 3274    1
# 3275    1
# Name: Potability, Length: 3276, dtype: int64

# %% [markdown]
# ## Data Visualisation

# %%
df.hist(figsize=(10,10))
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),annot=True,cmap='rainbow')#cmap=colormap
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.countplot(x='Potability',data=df)

plt.subplot(1,2,2)
a=df['Potability'].value_counts()
plt.pie(a,labels=[0,1])
plt.legend()
plt.show()

# %%
df.boxplot(figsize=(10,10))
# Out:
# <Axes: >

# %%
IQR=df["Solids"].quantile(0.75)-df["Solids"].quantile(0.25)
lower_bound=df["Solids"].quantile(0.25)-(IQR*1.5)
upper_bound=df["Solids"].quantile(0.75)+(IQR*1.5)
print(IQR)
print(lower_bound)
print(upper_bound)
# Out:
# 11666.071830473964
# -1832.4174487462951
# 44831.86987314956

# %%
df["df_replace"]=pd.DataFrame(np.where(df["Solids"]>upper_bound,upper_bound,np.where(df["Solids"]<lower_bound,lower_bound,df["Solids"])))
plt.boxplot(df.df_replace)
plt.show()

# %% [markdown]
# ## Scaling using MinMax Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
X_s=m.fit_transform(X)
X_s
# Out:
# array([[0.50577104, 0.57113901, 0.33609646, ..., 0.31340165, 0.69975313,
#         0.28609102],
#        [0.26543429, 0.29740043, 0.30061142, ..., 0.49731851, 0.4509993 ,
#         0.57679264],
#        [0.57850887, 0.64131081, 0.32161885, ..., 0.56201674, 0.5328657 ,
#         0.30363656],
#        ...,
#        [0.67282217, 0.46548556, 0.53910122, ..., 0.33866167, 0.56065454,
#         0.34956996],
#        [0.36619735, 0.66440723, 0.19148981, ..., 0.34363779, 0.62265916,
#         0.61611996],
#        [0.56247653, 0.53563505, 0.28048408, ..., 0.5341137 , 0.63247754,
#         0.16244074]])

# %% [markdown]
# ## Splitting the data for training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_s,y,test_size=0.3,random_state=1)

# %%
X_train.shape,X_test.shape
# Out:
# ((2293, 9), (983, 9))

# %%
y_train.shape,y_test.shape
# Out:
# ((2293,), (983,))

# %% [markdown]
# ## Model creation using default parameter

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve

k=KNeighborsClassifier(n_neighbors=5)
s=SVC (kernel='rbf')
g=GaussianNB()
d=DecisionTreeClassifier(criterion='entropy') 
r=RandomForestClassifier(random_state=1)
a=AdaBoostClassifier()
xgb=XGBClassifier()
gr=GradientBoostingClassifier()
lists=[]
l=[k,s,g,d,r,a,xgb,gr]
for i in l:
    print(i)
    i.fit(X_train,y_train)
    y_pred=i.predict(X_test)
    lists.append(accuracy_score(y_test, y_pred)*100)
    print(accuracy_score(y_test,y_pred)*100)
# Out:
# KNeighborsClassifier()
# 61.241098677517805
# SVC()
# 65.41200406917599
# GaussianNB()
# 61.953204476093596
# DecisionTreeClassifier(criterion='entropy')
# 58.494404883011185
# RandomForestClassifier(random_state=1)
# 65.20854526958291
# AdaBoostClassifier()
# 59.61342828077314
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %%
data=pd.DataFrame(lists,index=['KNN','SVC','NB','DECISIONTREE','RANDOMFOREST','ADABOOST','XGBOOST','GRADIENTBOOST'],columns=['default parameters'])
data
# Out:
#                default parameters
# KNN                     61.241099
# SVC                     65.412004
# NB                      61.953204
# DECISIONTREE            58.494405
# RANDOMFOREST            65.208545
# ADABOOST                59.613428
# XGBOOST                 62.868769
# GRADIENTBOOST           62.970498

# %% [markdown]
# ## Hyper parameter tuning

# %%
KNeighborsClassifier().get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
#knn
from sklearn.model_selection import GridSearchCV
p={'n_neighbors':[1,3,5,7,9],'weights':['uniform','distance'],'algorithm':['auto','ball_tree','kd_tree','brute']}
clf=GridSearchCV(k,p,cv=5,scoring='accuracy')
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 9, 'weights': 'distance'}

# %%
#svc
p={'kernel':['linear','poly','rbf']}
clf=GridSearchCV(s,p,cv=5,scoring='accuracy')
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'kernel': 'rbf'}

# %%
#decisiontree
p={'criterion':['gini','entropy'],'max_depth':[2,3,4,5,6],'random_state':[1,2,3,4,5]}
clf=GridSearchCV(d,p,cv=5,scoring='accuracy')
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 4, 'random_state': 1}

# %%
#randomforest
p={'n_estimators':[100,150,200],'max_depth':[1,2,3,4,5],'random_state':[1,2,3,4,5]}
clf=GridSearchCV(r,p,cv=5,scoring='accuracy')
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'max_depth': 5, 'n_estimators': 100, 'random_state': 4}

# %%
#adaboost
p={'n_estimators':[100,150,200],'random_state':[1,2,3,4,5]}
clf=GridSearchCV(a,p,cv=5,scoring='accuracy')
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'n_estimators': 100, 'random_state': 1}

# %%
#gradient
p={'n_estimators':[100,150,200],'max_depth':[1,2,3,4,5],'random_state':[1,2,3,4,5]}
clf=GridSearchCV(gr,p,cv=5,scoring='accuracy')
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'max_depth': 4, 'n_estimators': 100, 'random_state': 4}

# %%
#xgb
p={'n_estimators':[100,150,200],'max_depth':[1,2,3,4,5],'random_state':[1,2,3,4,5]}
clf=GridSearchCV(xgb,p,cv=5,scoring='accuracy')
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'max_depth': 3, 'n_estimators': 100, 'random_state': 1}

# %%
GaussianNB().get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
k1=KNeighborsClassifier(algorithm='auto',n_neighbors=9,weights='distance')
s1=SVC(kernel='rbf')
d1=DecisionTreeClassifier(criterion='entropy',max_depth=4,random_state=1) 
r1=RandomForestClassifier(max_depth=5,n_estimators=100,random_state=4)
a1=AdaBoostClassifier(n_estimators=100,random_state=1 )
xgb1=XGBClassifier(max_depth=4,n_estimators=100,random_state=4)
gr1=GradientBoostingClassifier(max_depth=3,n_estimators=100,random_state=1)
lists1=[]
l1=[k1,s1,d1,r1,a1,xgb1,gr1]
for i in l1:
    print(i)
    i.fit(X_train,y_train)
    y_pred=i.predict(X_test)
    lists1.append(accuracy_score(y_test, y_pred)*100)
    print(accuracy_score(y_test,y_pred)*100)
# Out:
# KNeighborsClassifier(n_neighbors=9, weights='distance')
# 62.05493387589013
# SVC()
# 65.41200406917599
# DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=1)
# 63.47914547304171
# RandomForestClassifier(max_depth=5, random_state=4)
# 62.56358087487284
# AdaBoostClassifier(n_estimators=100, random_state=1)
# 60.223804679552394
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
data1=pd.DataFrame(lists1,index=['KNN','SVC','DECISIONTREE','RANDOMFOREST','ADABOOST','XGBOOST','GRADIENTBOOST'],columns=['hyper parameters'])
data1
# Out:
#                hyper parameters
# KNN                   62.054934
# SVC                   65.412004
# DECISIONTREE          63.479145
# RANDOMFOREST          62.563581
# ADABOOST              60.223805
# XGBOOST               62.665310
# GRADIENTBOOST         62.970498

# %% [markdown]
# ## Over sampling

# %% [markdown]
# increase the no of minority samples in the dataset

# %%
from imblearn.over_sampling import SMOTE
o=SMOTE(random_state=1)
X_os,y_os=o.fit_resample(X,y)

# %%
y.value_counts()
# Out:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %%
y_os.value_counts()
# Out:
# Potability
# 0    1998
# 1    1998
# Name: count, dtype: int64

# %%
X_o=m.fit_transform(X_os)
X_o
# Out:
# array([[0.50577104, 0.57113901, 0.33609646, ..., 0.31340165, 0.69975313,
#         0.28609102],
#        [0.26543429, 0.29740043, 0.30061142, ..., 0.49731851, 0.4509993 ,
#         0.57679264],
#        [0.57850887, 0.64131081, 0.32161885, ..., 0.56201674, 0.5328657 ,
#         0.30363656],
#        ...,
#        [0.55130697, 0.48054537, 0.46044472, ..., 0.52076671, 0.61092043,
#         0.45663706],
#        [0.46389233, 0.50396345, 0.58342833, ..., 0.43962246, 0.54357076,
#         0.41480097],
#        [0.32957159, 0.48696713, 0.30116148, ..., 0.44771604, 0.57160918,
#         0.40349809]])

# %%
X_train1,X_test1,y_train1,y_test1=train_test_split(X_o,y_os,test_size=0.3,random_state=1)

# %% [markdown]
# ## Over sampling with default parameter

# %%
k_o=KNeighborsClassifier(n_neighbors=5)
s_o=SVC (kernel='rbf')
g_o=GaussianNB()
d_o=DecisionTreeClassifier(criterion='entropy') 
r_o=RandomForestClassifier(random_state=1)
a_o=AdaBoostClassifier()
xgb_o=XGBClassifier()
gr_o=GradientBoostingClassifier()
lists2=[]
l_o=[k_o,s_o,g_o,d_o,r_o,a_o,xgb_o,gr_o]
for i in l_o:
    print(i)
    i.fit(X_train1,y_train1)
    y_pred_o=i.predict(X_test1)
    lists2.append(accuracy_score(y_test1, y_pred_o)*100)
    print(accuracy_score(y_test1,y_pred_o)*100)
# Out:
# KNeighborsClassifier()
# 65.8882402001668
# SVC()
# 67.13928273561301
# GaussianNB()
# 56.38031693077564
# DecisionTreeClassifier(criterion='entropy')
# 59.466221851542954
# RandomForestClassifier(random_state=1)
# 72.47706422018348
# AdaBoostClassifier()
# 60.30025020850709
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %%
data2=pd.DataFrame(lists2,index=['KNN','SVC','NB','DECISIONTREE','RANDOMFOREST','ADABOOST','XGBOOST','GRADIENTBOOST'],columns=['over sampling-default parameters'])
data2
# Out:
#                over sampling-default parameters
# KNN                                   65.888240
# SVC                                   67.139283
# NB                                    56.380317
# DECISIONTREE                          59.466222
# RANDOMFOREST                          72.477064
# ADABOOST                              60.300250
# XGBOOST                               65.304420
# GRADIENTBOOST                         64.053378

# %% [markdown]
# ## Over sampling with hyper parameter

# %%
k2=KNeighborsClassifier(algorithm='auto',n_neighbors=9,weights='distance')
s2=SVC(kernel='rbf')
d2=DecisionTreeClassifier(criterion='entropy',max_depth=4,random_state=1) 
r2=RandomForestClassifier(max_depth=5,n_estimators=100,random_state=4)
a2=AdaBoostClassifier(n_estimators=100,random_state=1 )
xgb2=XGBClassifier(max_depth=4,n_estimators=100,random_state=4)
gr2=GradientBoostingClassifier(max_depth=3,n_estimators=100,random_state=1)
lists3=[]
l2=[k2,s2,d2,r2,a2,xgb2,gr2]
for i in l2:
    print(i)
    i.fit(X_train1,y_train1)
    y_pred2=i.predict(X_test1)
    lists3.append(accuracy_score(y_test1, y_pred2)*100)
    print(accuracy_score(y_test1,y_pred2)*100)
# Out:
# KNeighborsClassifier(n_neighbors=9, weights='distance')
# 65.97164303586321
# SVC()
# 67.13928273561301
# DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=1)
# 52.71059216013344
# RandomForestClassifier(max_depth=5, random_state=4)
# 62.63552960800667
# AdaBoostClassifier(n_estimators=100, random_state=1)
# 59.966638865721436
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
data3=pd.DataFrame(lists3,index=['KNN','SVC','DECISIONTREE','RANDOMFOREST','ADABOOST','XGBOOST','GRADIENTBOOST'],columns=['over sampling-hyper parameters'])
data3
# Out:
#                over sampling-hyper parameters
# KNN                                 65.971643
# SVC                                 67.139283
# DECISIONTREE                        52.710592
# RANDOMFOREST                        62.635530
# ADABOOST                            59.966639
# XGBOOST                             66.055046
# GRADIENTBOOST                       65.304420

# %% [markdown]
# ## Under sampling

# %% [markdown]
# decrease the no of majority samples in the data set

# %%
from imblearn.under_sampling import RandomUnderSampler
u=RandomUnderSampler(random_state=1)
X_us,y_us=u.fit_resample(X,y)

# %%
y.value_counts()
# Out:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %%
y_us.value_counts()
# Out:
# Potability
# 0    1278
# 1    1278
# Name: count, dtype: int64

# %%
X_u=m.fit_transform(X_us)
X_u
# Out:
# array([[0.51475354, 0.36515796, 0.21798999, ..., 0.42447877, 0.58377683,
#         0.4102081 ],
#        [0.49238787, 0.68499219, 0.12958981, ..., 0.35979719, 0.73780185,
#         0.62938328],
#        [0.42578868, 0.47606058, 0.2807453 , ..., 0.54550633, 0.63874655,
#         0.67741632],
#        ...,
#        [0.69041535, 0.46548556, 0.53910122, ..., 0.33866167, 0.56065454,
#         0.34956996],
#        [0.36798551, 0.66440723, 0.19148981, ..., 0.34363779, 0.62265916,
#         0.61611996],
#        [0.57438193, 0.53563505, 0.28048408, ..., 0.5341137 , 0.63247754,
#         0.16244074]])

# %%
X_train2,X_test2,y_train2,y_test2=train_test_split(X_u,y_us,test_size=0.3,random_state=1)

# %% [markdown]
# ## Under sampling with default parameters

# %%
k_u=KNeighborsClassifier(n_neighbors=5)
s_u=SVC (kernel='rbf')
g_u=GaussianNB()
d_u=DecisionTreeClassifier(criterion='entropy') 
r_u=RandomForestClassifier(random_state=1)
a_u=AdaBoostClassifier()
xgb_u=XGBClassifier()
gr_u=GradientBoostingClassifier()
lists4=[]
l_u=[k_u,s_u,g_u,d_u,r_u,a_u,xgb_u,gr_u]
for i in l_u:
    print(i)
    i.fit(X_train2,y_train2)
    y_pred_u=i.predict(X_test2)
    lists4.append(accuracy_score(y_test2, y_pred_u)*100)
    print(accuracy_score(y_test2,y_pred_u)*100)
# Out:
# KNeighborsClassifier()
# 53.84615384615385
# SVC()
# 58.01825293350718
# GaussianNB()
# 54.758800521512384
# DecisionTreeClassifier(criterion='entropy')
# 56.32333767926988
# RandomForestClassifier(random_state=1)
# 61.408083441981745
# AdaBoostClassifier()
# 56.0625814863103
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %%
data4=pd.DataFrame(lists4,index=['KNN','SVC','NB','DECISIONTREE','RANDOMFOREST','ADABOOST','XGBOOST','GRADIENTBOOST'],columns=['under sampling-default parameters'])
data4
# Out:
#                under sampling-default parameters
# KNN                                    53.846154
# SVC                                    58.018253
# NB                                     54.758801
# DECISIONTREE                           56.323338
# RANDOMFOREST                           61.408083
# ADABOOST                               56.062581
# XGBOOST                                55.671447
# GRADIENTBOOST                          58.279009

# %% [markdown]
# ## Under sampling with hyper parameter

# %%
k3=KNeighborsClassifier(algorithm='auto',n_neighbors=9,weights='distance')
s3=SVC(kernel='rbf')
d3=DecisionTreeClassifier(criterion='entropy',max_depth=4,random_state=1) 
r3=RandomForestClassifier(max_depth=5,n_estimators=100,random_state=4)
a3=AdaBoostClassifier(n_estimators=100,random_state=1 )
xgb3=XGBClassifier(max_depth=4,n_estimators=100,random_state=4)
gr3=GradientBoostingClassifier(max_depth=3,n_estimators=100,random_state=1)
lists5=[]
l3=[k3,s3,d3,r3,a3,xgb3,gr3]
for i in l3:
    print(i)
    i.fit(X_train2,y_train2)
    y_pred3=i.predict(X_test2)
    lists5.append(accuracy_score(y_test2, y_pred3)*100)
    print(accuracy_score(y_test2,y_pred3)*100)
# Out:
# KNeighborsClassifier(n_neighbors=9, weights='distance')
# 56.32333767926988
# SVC()
# 58.01825293350718
# DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=1)
# 54.758800521512384
# RandomForestClassifier(max_depth=5, random_state=4)
# 56.32333767926988
# AdaBoostClassifier(n_estimators=100, random_state=1)
# 53.45501955671447
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
data5=pd.DataFrame(lists3,index=['KNN','SVC','DECISIONTREE','RANDOMFOREST','ADABOOST','XGBOOST','GRADIENTBOOST'],columns=['under sampling-hyper parameters'])
data5
# Out:
#                under sampling-hyper parameters
# KNN                                  65.971643
# SVC                                  67.139283
# DECISIONTREE                         52.710592
# RANDOMFOREST                         62.635530
# ADABOOST                             59.966639
# XGBOOST                              66.055046
# GRADIENTBOOST                        65.304420

# %%
datas=pd.concat([data,data1,data2,data3,data4,data5],axis=1)
datas
# Out:
#                default parameters  hyper parameters  \
# KNN                     61.241099         62.054934
# SVC                     65.412004         65.412004
# NB                      61.953204               NaN
# DECISIONTREE            58.494405         63.479145
# RANDOMFOREST            65.208545         62.563581
# ADABOOST                59.613428         60.223805
# XGBOOST                 62.868769         62.665310
# GRADIENTBOOST           62.970498         62.970498
#
#                over sampling-default parameters  \
# KNN                                   65.888240
# SVC                                   67.139283
# NB                                    56.380317
# DECISIONTREE                          59.466222
# RANDOMFOREST                          72.477064
# ADABOOST                              60.300250
# XGBOOST                               65.304420
# GRADIENTBOOST                         64.053378
#
#                over sampling-hyper parameters  \
# ...

# %% [markdown]
# ## FEATURE SELECTION

# %%
df.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.075833 -0.081884    -0.031811  0.014403
# Hardness         0.075833  1.000000 -0.046899    -0.030054 -0.092766
# Solids          -0.081884 -0.046899  1.000000    -0.070148 -0.149840
# Chloramines     -0.031811 -0.030054 -0.070148     1.000000  0.023791
# Sulfate          0.014403 -0.092766 -0.149840     0.023791  1.000000
# Conductivity     0.017192 -0.023915  0.013831    -0.020486 -0.014059
# Organic_carbon   0.040061  0.003610  0.010242    -0.012653  0.026909
# Trihalomethanes  0.002994 -0.012690 -0.008875     0.016627 -0.025605
# Turbidity       -0.036222 -0.014449  0.019546     0.002363 -0.009790
# Potability      -0.003287 -0.013837  0.033743     0.023779 -0.020619
# df_replace      -0.082627 -0.046349  0.997261    -0.067368 -0.148126
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ...

# %% [markdown]
# ## Deploy model

# %% [markdown]
# here the best algorithm id Randomforestclassifier using oversampling with using default parameters.it gives 72% accuracy. so weselect the model for water potablilty is Randomforestclassifier

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

ra=RandomForestClassifier(random_state=1)
ra.fit(X_train1,y_train1)
y_pred_r=ra.predict(X_test1)
print(classification_report(y_test1,y_pred_r))
print(ConfusionMatrixDisplay.from_predictions(y_test1,y_pred_r))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.73       593
#            1       0.74      0.71      0.72       606
#
#     accuracy                           0.72      1199
#    macro avg       0.73      0.72      0.72      1199
# weighted avg       0.73      0.72      0.72      1199
#
# ...

# %%
# auc scores
auc_score=roc_auc_score(y_test1,y_pred_r)
print(auc_score)
# Out:
# 0.7249191613933736

# %%
# roc curve for model
fpr,tpr,thresh=roc_curve(y_test1,y_pred_r)
#plot roc curve
plt.style.use('seaborn-v0_8')
plt.plot(fpr,tpr,linestyle='--',color='orange',label='ROC Curve(AUC=%0.2f)'% auc_score)
plt.plot([0,1],[0,1],color='navy',linestyle=':')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show();

# %%
import pickle
pickle.dump(ra,open('water1','wb'))
pickle.dump(m,open('scaler1','wb'))
